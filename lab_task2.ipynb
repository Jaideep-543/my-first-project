# %% [markdown]
# <a href="https://colab.research.google.com/github/Jaideep-543/my-first-project/blob/main/lab_task2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Hard-coded values
length = 12
width = 8

area = length * width
print("Length:", length)
print("Width:", width)
print("Area of Rectangle:", area)
# Out:
# Length: 12
# Width: 8
# Area of Rectangle: 96

# %%
# Accepting input from user
student_name = input("Enter student name: ")
marks = int(input("Enter marks: "))

try:
    marks = int(marks)
    if marks >= 50 and marks <= 100:
        result = "Pass"
    elif marks >= 0 and marks < 50:
        result = "Fail"
    else:
      print("Marks should be between 0 and 100.")
      exit()
except ValueError:
    print("Invalid input. Marks should be a number.")
    exit()

print("Name:", student_name)
print("Marks:", marks)
print("Result:", result)
# Out:
# Enter student name: a
# Enter marks: 324
# Marks should be between 0 and 100.
# Name: a
# Marks: 324
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3791705147.py in <cell line: 0>()
#      18 print("Name:", student_name)
#      19 print("Marks:", marks)
# ---> 20 print("Result:", result)
#
# NameError: name 'result' is not defined

# %%
# Reading a single value from file
file = open("single_value.txt", "w")
file.write("7")
file.close()

try:
    file = open("single_value.txt", "r")
    number = int(file.read())
    file.close()

    print("Number from file:", number)
    print("Square of number:", number * number)

except FileNotFoundError:
    print("Error: File not found")
except ValueError:
    print("Error: Invalid data in file")
# Out:
# Number from file: 7
# Square of number: 49

# %%
# Reading multiple values from file
file = open("numbers.txt", "w")
file.write("10\n20\n30\n40\n50")
file.close()


try:
    file = open("numbers.txt", "r")
    values = file.readlines()
    file.close()

    total = 0
    for val in values:
        total += int(val.strip())

    print("Numbers read:", values)
    print("Sum of numbers:", total)

except FileNotFoundError:
    print("File not found")
except ValueError:
    print("Error: Invalid data in file")
# Out:
# Numbers read: ['10\n', '20\n', '30\n', '40\n', '50']
# Sum of numbers: 150
