# %% [markdown]
# <a href="https://colab.research.google.com/github/Jaideep-543/my-first-project/blob/main/Weather_Modelling_using_Waterfall_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Define the quadratic function
def quadratic(x, a=-1, b=0, c=10):
    return a * x**2 + b * x + c

# %%
# Define the stages of the Waterfall Model
stages = ["Requirements", "Design", "Implementation", "Verification", "Maintenance"]

# Generate x positions for stages
x_positions = np.linspace(-2, 2, len(stages))

# Compute y positions using the quadratic function
y_positions = quadratic(x_positions)

# %%
# Plot the quadratic curve
x_curve = np.linspace(-2.5, 2.5, 500)
y_curve = quadratic(x_curve)

plt.figure(figsize=(10, 6))
plt.plot(x_curve, y_curve, color="blue", linestyle="--", label="Quadratic Curve")
# Add straight waterfall connections (horizontal + vertical)
for i in range(1, len(stages)):
    # Horizontal line
    plt.plot(
        [x_positions[i-1], x_positions[i]],
        [y_positions[i-1], y_positions[i-1]],
        color="blue",
        linewidth=2
    )

    # Vertical drop
    plt.plot(
        [x_positions[i], x_positions[i]],
        [y_positions[i-1], y_positions[i]],
        color="blue",
        linewidth=2
    )
    # Plot stage markers and labels
plt.scatter(x_positions, y_positions, color="red", zorder=5)

for i, stage in enumerate(stages):
    plt.text(
        x_positions[i],
        y_positions[i] + 0.3,
        stage,
        ha="center",
        fontsize=10
    )
    # Style the plot
plt.title("Waterfall Model Representation Using Quadratic Curve", fontsize=14)
plt.xlabel("Stages", fontsize=12)
plt.ylabel("Value", fontsize=12)

plt.axhline(0, color="black", linewidth=0.5, linestyle="--")
plt.axvline(0, color="black", linewidth=0.5, linestyle="--")

plt.grid(color="gray", linestyle="--", linewidth=0.5, alpha=0.7)
plt.legend()
plt.show()
